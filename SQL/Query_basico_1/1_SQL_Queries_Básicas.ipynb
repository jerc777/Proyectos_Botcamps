# %% [markdown]
# <h1>Índice del Reto Guiado de SQL. Queries Básicas</h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li>
#             <span><a href="#1-resumen-del-1º-reto-guiado-sql-queries-básicas">1. Resumen del 1º Reto Guiado SQL: Queries Básicas.</a></span>
#             <ul class="toc-item">
#                 <li><span><a href="#11-conocimientos-previos">1.1. Conocimientos previos.</a></span></li>
#                 <li><span><a href="#12-propósito-del-reto">1.2. Propósito del reto.</a></span></li>
#             </ul>
#         </li>
#         <li>
#             <span><a href="#2-instalación-de-la-base-de-datos-sakila">2. Instalación de la Base de datos Sakila.</a></span>
#         </li>
#         <li>
#             <span><a href="#3-ejercicios">3. Ejercicios</a></span>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# ## 1. Resumen del 1º Reto Guiado SQL: Queries Básicas.
# ### 1.1. Conocimientos previos.
# - SQL
# ### 1.2. Propósito del reto.
# En PowerCinema, una tienda de alquiler de películas ubicada en una zona urbana, estás asumiendo tu papel como analista de datos. La tienda ofrece una amplia variedad de películas, desde clásicos del cine hasta lanzamientos más recientes, atrayendo a una clientela diversa.
#
# La gerencia de PowerCinema busca comprender mejor el comportamiento de sus clientes y optimizar la operación de la tienda. Quieren identificar qué películas son las más solicitadas por diferentes grupos de clientes, cómo varía el patrón de alquiler de películas a lo largo del tiempo y cómo se distribuyen los ingresos por concepto de alquileres entre los diversos géneros de películas.
#
# Para realizar análisis de manera efectiva, se utilizará la base de datos Sakila en PostgreSQL como el sistema de gestión de base de datos para realizar consultas significativas y extraer información clave. La gerencia espera que puedas descubrir tendencias, patrones de comportamiento y áreas de oportunidad que puedan utilizarse para mejorar la experiencia del cliente y aumentar la rentabilidad de la tienda.
#
# A lo largo de distintas sesiones iremos profundizando en el estudio de los datos de Sakila realizando consultas cada vez más complejas. En esta primera sesión realizaremos consultas básicas y usaremos funciones de agregación.
# ## 2. Instalación de la Base de datos Sakila.
# 2.1. Abrimos el programa de Postgress y seleccionarmos servers, a continuación introducimos la contraseña.
#
# ![2.png](attachment:2.png)
#
# 2.2. A continuación hacemos click derecho sobre Database y seleccionamos Create y a continuación Database...
#
# ![3.png](attachment:3.png)
#
# 2.3. Se nos abrirá una ventana donde indicaremos el nombre de nuestra base de datos. En este caso, 'Sakila' y seleccionamos Save
#
# ![4.png](attachment:4.png)
#
# 2.4. Ahora sobre la base de datos Sakila hacemos click derecho y seleccionamos CREATE Script
#
# ![5.png](attachment:5.png)
#
# 2.5. Se nos abrirá un script para hacer consultas. Seleccionaremos abrir archivo. Nos preguntará si queremos descartar los cambios actuales, le damos que sí y abriremos el archivo 'sakila.sql'
#
# ![6.png](attachment:6.png)
#
# 2.6. Una vez abierto el archivo seleccionamos todo el script y le damos a ejecutar.
#
# ![8.png](attachment:8.png)
#
# 2.7. Nos aparecerá un mensaje en la esquina inferior derecha indicándonos que todo se ejecutó correctamente. Ya tendríamos nuestra base de datos Sakila cargada.
#
# 2.8. Por último, abrimos un nuevo Script para empezar a hacer consultas y ya podríamos empezar con el reto guiado.
#
# ![10.png](attachment:10.png)
#
# ## 3. Ejercicios
# 3.1. Crea el esquema de la BBDD de sakila
#
# 3.2. Selecciona todos los nombres de las películas úncos.
#
# 3.3. Crea una columna con el nombre y apellidos de todos los actores y actrices.
#
# 3.4. Muestra los nombres de todas las películas con una clasificación por edades de "R".
#
# 3.5. Obtén las películas que tenemos cuyo idioma conicide con el idioma original.
#
# 3.6. Encuentra el nombre y apellido de los actores que tengan "Allen" en su apellido.
#
# 3.7. Encuentra el título de todas las películas que tengan una duración mayor a 180 minutos.
#
# 3.8. Encuentra los nombres de los actores que tengan un actor_id entre 30 y 40.
#
# 3.9. Encuentra el título de las películas en la tabla film que no sean ni "NC-17" ni "G" en cuanto a su clasificación.
#
# 3.10. Encuentra el título de todas las películas que son "PG-13" o tienen una duración mayor a 3 horas en la tabla film.
#
# 3.11. Encuentra la mayor y menor duración de una película de nuestra BBDD
#
# 3.12. ¿Cuántas películas distintas tenemos?
#
# 3.13. ¿Cuánto dinero ha generado en total la empresa?
#
# 3.14. ¿Cuál es la media de duración del alquiler de las películas?
#
# 3.15. Encuentra la variabilidad de los que costaría reemplazar las películas.
